# %%
a, b, c=input('Enter your full name ').split()
print(a, b, c)
a, b, c=[int(n) for n in input('Enter the numbers ').split()]
print((a*2), (b*3), (c*5))

# %%
elements=input('Enter the elements ').split()
i=int(elements[0])
f=float(elements[1])
c=elements[2]
s=elements[3]
print(i+f)
print(c+s)

# %%
elements=[int(n) for n in input('Enter the numbers ').split()]
for i, v in enumerate(elements) :
  print(i, v, sep='=>')

# %%
print('Length is {} metres, Width is {} metres and Height is {} metres'.format(99, 66, 33))
