# %%
def fact(n) :
  if n==0 or n==1 :
    return 1
  else :
    return (n*fact(n-1))
print(fact(10))

# %%
def fibon(n) :
  if n==1 or n==2 :
    return (n-1)
  else :
    return (fibon(n-1)+fibon(n-2))
print(fibon(10))
